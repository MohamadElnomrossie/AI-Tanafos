# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
import seaborn as sb
import scipy.stats as st
import joblib

# %%
X,y=fetch_california_housing(return_X_y=True)

# %%
transformer=PolynomialFeatures()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
ply_X=transformer.fit_transform(X_train)

# %%
lr=LinearRegression()

# %%
lr.fit(ply_X,y_train)
# Out:
# LinearRegression()

# %%
X_test_ply=transformer.transform(X_test)

# %%
y_train.shape
# Out:
# (15480,)

# %%
X_test_ply.shape
# Out:
# (5160, 45)

# %%
lr.predict(X_test_ply)
# Out:
# array([2.02019515, 1.94176804, 1.1369122 , ..., 2.29268222, 2.26758099,
#        2.78191362])

# %%
transformer.get_feature_names_out()
# Out:
# array(['1', 'x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x0^2',
#        'x0 x1', 'x0 x2', 'x0 x3', 'x0 x4', 'x0 x5', 'x0 x6', 'x0 x7',
#        'x1^2', 'x1 x2', 'x1 x3', 'x1 x4', 'x1 x5', 'x1 x6', 'x1 x7',
#        'x2^2', 'x2 x3', 'x2 x4', 'x2 x5', 'x2 x6', 'x2 x7', 'x3^2',
#        'x3 x4', 'x3 x5', 'x3 x6', 'x3 x7', 'x4^2', 'x4 x5', 'x4 x6',
#        'x4 x7', 'x5^2', 'x5 x6', 'x5 x7', 'x6^2', 'x6 x7', 'x7^2'],
#       dtype=object)

# %%
ls=Lasso(alpha=.5)#L1
rg=Ridge(alpha=.6)#L2

# %%
ls.fit(ply_X,y_train)
ls.score(X_test_ply,y_test)
# Out:
# C:\Users\HP Zbook Fury 15 G7\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.669e+03, tolerance: 2.055e+00
#   model = cd_fast.enet_coordinate_descent(
# -0.016971311249831755

# %%
rg.fit(X_train,y_train)
rg.score(X_test,y_test)
# Out:
# 0.5988002200447061

# %%
# Out:
# 0.4498374530843182

# %%
# Out:
# 0.5988012905801887

# %%
lr2=LinearRegression()
lr2.fit(X_train,y_train)
lr2.score(X_test,y_test)
# Out:
# 0.5987985841521111

# %% [markdown]
# # Lasso and Ridge

# %%
ls=Lasso()
ls.fit(X_train,y_train)
ls.coef_
# Out:
# array([ 1.50331238e-01,  6.05794356e-03,  0.00000000e+00, -0.00000000e+00,
#        -6.16592406e-06, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00])

# %%
rid=Ridge()
rid.fit(X_train,y_train)
rid.coef_
# Out:
# array([ 4.44222630e-01,  9.66366044e-03, -1.17613930e-01,  7.33832242e-01,
#        -3.62354123e-06, -3.47123667e-03, -4.20749222e-01, -4.35599935e-01])

# %%
en=ElasticNet()
en.fit(X_train,y_train)
en.coef_
# Out:
# array([ 2.56286763e-01,  1.15338585e-02,  0.00000000e+00, -0.00000000e+00,
#         8.47331574e-06, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00])

# %%
weights=np.random.random(size=(8,1))
bias=-.5

# %%
y_hat=X_train.dot(weights)+bias

# %%
y_hat
# Out:
# array([[ 474.51181373],
#        [1268.9919854 ],
#        [ 630.42142499],
#        ...,
#        [ 800.56829595],
#        [1333.58991632],
#        [ 906.5806369 ]])

# %%
np.sum((y_train-y_hat)**2)/X_train.shape[0]
# Out:
# np.float64(35466881120.998726)

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
sigmoid(35466881120.998726)
# Out:
# np.float64(1.0)

# %%
np.log(0)
# Out:
# C:\Users\HP Zbook Fury 15 G7\AppData\Local\Temp\ipykernel_3092\2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# np.float64(-inf)

# %%
import joblib

# %%
joblib.,
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pickle.dump(lr,"model.pkl")
#
# TypeError: file must have a 'write' attribute

# %%
with open('model',mode='xb') as m:
    m.write(lr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 with open('model',mode='xb') as m:
# ----> 2     m.write(lr)
#
# TypeError: a bytes-like object is required, not 'LinearRegression'

# %% [markdown]
# # Model Saving

# %%
joblib.dump(lr,"linear_model.pkl")
# Out:
# ['linear_model.pkl']

# %%
joblib.dump(transformer,"transformer.pkl")
# Out:
# ['transformer.pkl']

# %%
# We can save the steps (all transformations i.e. polynomial features)
# and model in one file by using pipelines

# %%
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline([('polynomial_transformer',PolynomialFeatures())
               ,('model',LinearRegression())])

# %%
pipe
# Out:
# Pipeline(steps=[('polynomial_transformer', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('polynomial_transformer', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %%
joblib.dump(pipe,'pipe.pkl')
# Out:
# ['pipe.pkl']
